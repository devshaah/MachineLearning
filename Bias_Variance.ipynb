# %%
#Variance = Error varies based on the training smaple selected
#High Variance happens when test error varies by great deal
#Low variance , slight changes in test error
#Bias -> measurement of how accurately a model can capture a pattern in training dataset.
#Bias -> based on train error
#Variance -> based on test error

# %% [markdown]
# ![Screenshot (623).png](data:image/png;base64,...)
